# %% [markdown]
# <a href="https://colab.research.google.com/github/AyeshathHafeeza/DataScience/blob/main/Student_Marks_Analysis_using_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Student Marks Analysis using Pandas**

# %%
# 1. student_marks.csv
import pandas as pd
df=pd.read_csv("/content/student_marks-pandas 2.csv")
df.head(10)
# Out:
#   Student  Subject  Marks Grade
# 0   Rahul     Math     88     A
# 1    Neha  Science     76     B
# 2   Aditi  English     92     A
# 3   Varun     Math     65     C
# 4   Rahul  Science     81     B
# 5    Neha  English     73     B

# %%
# Load the dataset and view first 5 rows.
df.head(5)
# Out:
#   Student  Subject  Marks Grade
# 0   Rahul     Math     88     A
# 1    Neha  Science     76     B
# 2   Aditi  English     92     A
# 3   Varun     Math     65     C
# 4   Rahul  Science     81     B

# %%
# Show number of students who scored grade A
# df.query("Grade=='A'")
df[df['Grade']=="A"]
# Out:
#   Student  Subject  Marks Grade
# 0   Rahul     Math     88     A
# 2   Aditi  English     92     A

# %%
df['Grade'].count()
# Out:
# np.int64(6)

# %%
# Find average marks scored in each subject.
df.groupby("Subject")["Marks"].mean()
# Out:
# Subject
# English    82.5
# Math       76.5
# Science    78.5
# Name: Marks, dtype: float64

# %%
# Which student scored the highest marks?
df.groupby("Student")['Marks'].max().head(1)
# Out:
# Student
# Aditi    92
# Name: Marks, dtype: int64

# %%
# Add a new column "Pass/Fail"
# Marks ≥ 40 → Pass
# Else → Fail

df['Pass/Fail']=df['Marks'].apply(lambda x:"Pass" if x>=40 else "Fail")
df.head(10)
# Out:
#   Student  Subject  Marks Grade Pass/Fail
# 0   Rahul     Math     88     A      Pass
# 1    Neha  Science     76     B      Pass
# 2   Aditi  English     92     A      Pass
# 3   Varun     Math     65     C      Pass
# 4   Rahul  Science     81     B      Pass
# 5    Neha  English     73     B      Pass

# %%
# Sort marks in descending order.
df.sort_values(by='Marks',ascending=False)
# Out:
#   Student  Subject  Marks Grade Pass/Fail
# 2   Aditi  English     92     A      Pass
# 0   Rahul     Math     88     A      Pass
# 4   Rahul  Science     81     B      Pass
# 1    Neha  Science     76     B      Pass
# 5    Neha  English     73     B      Pass
# 3   Varun     Math     65     C      Pass
